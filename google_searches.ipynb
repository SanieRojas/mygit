# %% [markdown]
# <a href="https://colab.research.google.com/github/SanieRojas/own_datascience_projects/blob/main/google_searches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install GoogleNews
# Out:
# Collecting GoogleNews
#   Downloading GoogleNews-1.6.10-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from GoogleNews) (4.11.2)
# Collecting dateparser (from GoogleNews)
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from GoogleNews) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->GoogleNews) (2.5)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (2023.6.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->GoogleNews) (1.16.0)
# Installing collected packages: dateparser, GoogleNews
# Successfully installed GoogleNews-1.6.10 dateparser-1.1.8

# %%
from GoogleNews import GoogleNews
import pandas as pd

# %%
def setup_engine(period):
    """
    Set up the google engine to retrieve news of a given period.

    :period: defines how much time to search news for.
    :type parameter1: 7d [quantity of days + "d"]

    Next iteration

    :return: none
    """
    # Function code goes here
    api = GoogleNews()
    api.set_lang("en")
    api.set_encode("utf-8")
    api.set_period(period)

    # You can access parameter1 and parameter2 within the function

    # If the function returns a value, use the "return" statement
    return api

# %%
def setup_subject(api, subject, category, monitor):
    """
    Performs a search of "period" days of news for any selected subject theme and, if prompted, saves it into a database.


    :monitor: Yes if you want to keep your results.
    :type parameter1: Boolean

    :category: Category of search subject
    :type parameter2: String

    :subject: Subject of interest
    :rtype: String

    :return: Newsfeed dataframe
    :rtype: pandas dataframe
    """
    # Function code goes here

    api.get_news(subject)
    #print & save results
    results = api.results(sort=True)

    newsfeed = pd.DataFrame(results)
    newsfeed = newsfeed.sort_values(by=["datetime"], ascending=False)

    if monitor == "yes":
        file_name = 'news_data.csv'
        newsfeed.to_csv(file_name, index=False)
        print("Corpus succesfully saved to file.")
    else:
        pass

    # If the function returns a value, use the "return" statement
    return newsfeed

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
step1 = setup_engine("1d")
step1

# %%
step2 = setup_subject(step1, "Apple", "Companies", "no")
step2
# Out:
#                                                  title  desc          date  \
# 0    Apple Suppliers in Taiwan Had Their Worst Mont...  None    1 hour ago
# 1    Apple Suppliers in Taiwan Had Their Worst Mont...  None    1 hour ago
# 2            The 17 best October Prime Day Apple deals  None   3 hours ago
# 3    Apple TV+ share compared to other streaming pl...  None   3 hours ago
# 4            The 17 best October Prime Day Apple deals  None   3 hours ago
# ..                                                 ...   ...           ...
# 195  How to watch Lionel Messi documentary on Apple TV  None  22 hours ago
# 196  LivePod turns your Apple Music Up Next queue i...  None  23 hours ago
# 197  Fare Report: Apple Butter | Bon Appetit | wvne...  None  23 hours ago
# 198  LivePod turns your Apple Music Up Next queue i...  None  23 hours ago
# 199  Fare Report: Apple Butter | Bon Appetit | wvne...  None  23 hours ago
#
#                       datetime  \
# 0   2023-10-12 02:37:26.014228
# 1   2023-10-12 02:37:12.110670
# 2   2023-10-12 00:37:26.030254
# 3   2023-10-12 00:37:26.020623
# 4   2023-10-12 00:37:12.125764
# ..                         ...
# 195 2023-10-11 05:37:12.101650
# 196 2023-10-11 04:37:26.032068
# 197 2023-10-11 04:37:26.026489
# 198 2023-10-11 04:37:12.127395
# 199 2023-10-11 04:37:12.122812
#
#                                                   link  \
# 0    news.google.com/./articles/CBMibWh0dHBzOi8vd3d...
# 1    news.google.com/./articles/CBMibWh0dHBzOi8vd3d...
# 2    news.google.com/./articles/CBMiRmh0dHBzOi8vd3d...
# 3    news.google.com/./articles/CBMiaWh0dHBzOi8vOXR...
# 4    news.google.com/./articles/CBMiRmh0dHBzOi8vd3d...
# ..                                                 ...
# 195  news.google.com/./articles/CBMiTmh0dHBzOi8vOXR...
# 196  news.google.com/./articles/CBMiSWh0dHBzOi8vOXR...
# 197  news.google.com/./articles/CBMifmh0dHBzOi8vd3d...
# 198  news.google.com/./articles/CBMiSWh0dHBzOi8vOXR...
# 199  news.google.com/./articles/CBMifmh0dHBzOi8vd3d...
#
#                                                    img      media  site
# 0    https://lh3.googleusercontent.com/NGEszdY4BPKj...  Bloomberg  None
# 1    https://lh3.googleusercontent.com/NGEszdY4BPKj...  Bloomberg  None
# 2    https://lh3.googleusercontent.com/t1D9YmnY4ufP...      ZDNet  None
# 3    https://lh3.googleusercontent.com/_yU7TVFBBY59...    9to5Mac  None
# 4    https://lh3.googleusercontent.com/t1D9YmnY4ufP...      ZDNet  None
# ..                                                 ...        ...   ...
# 195  https://lh3.googleusercontent.com/_yU7TVFBBY59...    9to5Mac  None
# 196  https://lh3.googleusercontent.com/_yU7TVFBBY59...    9to5Mac  None
# 197  https://encrypted-tbn3.gstatic.com/faviconV2?u...    WV News  None
# 198  https://lh3.googleusercontent.com/_yU7TVFBBY59...    9to5Mac  None
# 199  https://encrypted-tbn3.gstatic.com/faviconV2?u...    WV News  None
#
# [200 rows x 8 columns]

# %%
step2 = setup_subject(step1, "Accenture", "Companies", "yes")
step2
# Out:
# Corpus succesfully saved to file.
#                                                  title  desc            date  \
# 0    Cybersecurity should be a business priority fo...  None  38 minutes ago
# 1    Apple Suppliers in Taiwan Had Their Worst Mont...  None      1 hour ago
# 2    Apple Suppliers in Taiwan Had Their Worst Mont...  None      1 hour ago
# 3    Harvard student groups issued an anti-Israel s...  None     2 hours ago
# 4    'Pro-life Spiderman' arrested after scaling 40...  None     2 hours ago
# ..                                                 ...   ...             ...
# 293  Accenture books 13th consecutive year of growt...  None    23 hours ago
# 294  LivePod turns your Apple Music Up Next queue i...  None    23 hours ago
# 295  Fare Report: Apple Butter | Bon Appetit | wvne...  None    23 hours ago
# 296  LivePod turns your Apple Music Up Next queue i...  None    23 hours ago
# 297  Fare Report: Apple Butter | Bon Appetit | wvne...  None    23 hours ago
#
#                       datetime  \
# 0   2023-10-12 03:01:21.357279
# 1   2023-10-12 02:37:26.014228
# 2   2023-10-12 02:37:12.110670
# 3   2023-10-12 01:39:21.371243
# 4   2023-10-12 01:39:21.360683
# ..                         ...
# 293 2023-10-11 04:39:21.346361
# 294 2023-10-11 04:37:26.032068
# 295 2023-10-11 04:37:26.026489
# 296 2023-10-11 04:37:12.127395
# 297 2023-10-11 04:37:12.122812
#
#                                                   link  \
# 0    news.google.com/./articles/CBMiTWh0dHBzOi8vd3d...
# 1    news.google.com/./articles/CBMibWh0dHBzOi8vd3d...
# 2    news.google.com/./articles/CBMibWh0dHBzOi8vd3d...
# 3    news.google.com/./articles/CBMiVWh0dHBzOi8vd3d...
# 4    news.google.com/./articles/CBMioQFodHRwczovL3d...
# ..                                                 ...
# 293  news.google.com/./articles/CBMiamh0dHBzOi8vd3d...
# 294  news.google.com/./articles/CBMiSWh0dHBzOi8vOXR...
# 295  news.google.com/./articles/CBMifmh0dHBzOi8vd3d...
# 296  news.google.com/./articles/CBMiSWh0dHBzOi8vOXR...
# 297  news.google.com/./articles/CBMifmh0dHBzOi8vd3d...
#
#                                                    img               media  \
# 0    https://encrypted-tbn3.gstatic.com/faviconV2?u...   Help Net Security
# 1    https://lh3.googleusercontent.com/NGEszdY4BPKj...           Bloomberg
# 2    https://lh3.googleusercontent.com/NGEszdY4BPKj...           Bloomberg
# 3    https://lh3.googleusercontent.com/8zdvTbISHUn-...                 CNN
# 4    https://encrypted-tbn2.gstatic.com/faviconV2?u...         Pasco News
# ..                                                 ...                 ...
# 293  https://lh3.googleusercontent.com/proxy/JTsJWF...  Consultancy-me.com
# 294  https://lh3.googleusercontent.com/_yU7TVFBBY59...             9to5Mac
# 295  https://encrypted-tbn3.gstatic.com/faviconV2?u...             WV News
# 296  https://lh3.googleusercontent.com/_yU7TVFBBY59...             9to5Mac
# 297  https://encrypted-tbn3.gstatic.com/faviconV2?u...             WV News
#
#      site
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# ..    ...
# 293  None
# 294  None
# 295  None
# 296  None
# 297  None
#
# [298 rows x 8 columns]
